# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
Structure = 1
Method = "plain"
EPOCHS = 108
f_read = open('acc_train_00.pkl', 'rb')
acc_train0 = pickle.load(f_read)
f_read.close()
f_read = open('acc_tests_00.pkl', 'rb')
acc_tests0 = pickle.load(f_read)
f_read.close()

# %%
Structure = 1
Method = "cutout"
EPOCHS = 108
acc_train1 = [0.37784, 0.55282, 0.63256, 0.68082, 0.72, 0.74572, 0.76288, 0.7765, 0.79348, 0.80512, 0.81218, 0.82232, 0.82922, 0.83762, 0.84038, 0.84882, 0.85302, 0.85824, 0.8639, 0.86892, 0.87096, 0.87564, 0.87908, 0.88354, 0.88512, 0.88814, 0.89286, 0.89546, 0.89664, 0.89992, 0.90126, 0.90466, 0.90646, 0.90928, 0.91064, 0.91434, 0.91476, 0.91824, 0.92026, 0.92176, 0.92468, 0.92532, 0.92956, 0.9297, 0.9318, 0.93416, 0.9348, 0.93606, 0.93848, 0.93956, 0.94036, 0.94232, 0.94404, 0.94586, 0.94994, 0.94764, 0.9486, 0.9521, 0.95146, 0.9534, 0.9546, 0.9532, 0.95554, 0.9588, 0.95884, 0.96142, 0.9626, 0.96238, 0.96266, 0.96404, 0.965, 0.96512, 0.96748, 0.96722, 0.9697, 0.96958, 0.96982, 0.97018, 0.97378, 0.97304, 0.9723, 0.97298, 0.97342, 0.97488, 0.97502, 0.9757, 0.9745, 0.97548, 0.97652, 0.97654, 0.97794, 0.97754, 0.97806, 0.97884, 0.97802, 0.9787, 0.97776, 0.97936, 0.97976, 0.97832, 0.97888, 0.98024, 0.98, 0.97978, 0.97982, 0.97956, 0.9793, 0.98016]
acc_tests1 = [0.5088, 0.6098, 0.66, 0.7222, 0.7644, 0.7691, 0.816, 0.8014, 0.8177, 0.8238, 0.843, 0.8451, 0.8608, 0.8514, 0.8683, 0.8623, 0.8756, 0.8818, 0.8849, 0.8809, 0.8837, 0.8804, 0.8779, 0.8945, 0.8973, 0.8947, 0.8993, 0.9, 0.9017, 0.9027, 0.9026, 0.9117, 0.9055, 0.8988, 0.9126, 0.9045, 0.9077, 0.9205, 0.9071, 0.913, 0.9142, 0.9157, 0.9203, 0.919, 0.918, 0.9254, 0.9201, 0.922, 0.9185, 0.9238, 0.9239, 0.9177, 0.9231, 0.9227, 0.92, 0.927, 0.9261, 0.9244, 0.9269, 0.9289, 0.9314, 0.928, 0.9273, 0.9284, 0.9291, 0.9322, 0.9338, 0.934, 0.9363, 0.9348, 0.9371, 0.9359, 0.9353, 0.9366, 0.9375, 0.9342, 0.9371, 0.9372, 0.9385, 0.9397, 0.9404, 0.9402, 0.937, 0.9383, 0.9374, 0.9403, 0.9375, 0.9401, 0.9409, 0.9419, 0.9414, 0.9406, 0.94, 0.941, 0.9419, 0.9421, 0.9414, 0.9426, 0.9417, 0.9406, 0.9408, 0.941, 0.9429, 0.9421, 0.9415, 0.9418, 0.9425, 0.9422]

# %%
Structure = 1
Method = "autoaug"
EPOCHS = 108
f_read = open('acc_train_02.pkl', 'rb')
acc_train2 = pickle.load(f_read)
f_read.close()
f_read = open('acc_tests_02.pkl', 'rb')
acc_tests2 = pickle.load(f_read)
f_read.close()

# %%
Structure = 1
Method = "cutout"
EPOCHS = 200
261, 0.9296, 0.9291, 0.928, 0.9321, 0.9327, 0.9338, 0.9336, 0.9362, 0.9385, 0.9408, 0.933, 0.9303, 0.9386, 0.9391, 0.9335, 0.9386, 0.9419, 0.9381, 0.9383, 0.9343, 0.9313, 0.9357, 0.9348, 0.9417, 0.9391, 0.9408, 0.9329, 0.942, 0.9375, 0.9366, 0.9355, 0.9315, 0.9436, 0.9404, 0.9382, 0.9437, 0.9403, 0.9368, 0.9441, 0.9434, 0.9422, 0.9423, 0.9416, 0.9451, 0.9419, 0.9451, 0.9472, 0.9439, 0.9398, 0.945, 0.9437, 0.9451, 0.9457, 0.9457, 0.9471, 0.9456, 0.9416, 0.9495, 0.9508, 0.9444, 0.9473, 0.9494, 0.9485, 0.9482, 0.9485, 0.9487, 0.9491, 0.949, 0.9473, 0.9503, 0.9476, 0.95, 0.9512, 0.9526, 0.9518, 0.9522, 0.9527, 0.9536, 0.9532, 0.9525, 0.9526, 0.9539, 0.9532, 0.9532, 0.9521, 0.9551, 0.9541, 0.9532, 0.9541, 0.9531, 0.9547, 0.9541, 0.9549, 0.9535, 0.9529, 0.9531, 0.9525, 0.9528, 0.9556, 0.9562, 0.9554, 0.9554, 0.953, 0.9549, 0.9551, 0.9543, 0.954, 0.9566, 0.9555, 0.9557, 0.9565, 0.9553, 0.9558, 0.9547, 0.9551, 0.9549, 0.9558, 0.9554, 0.9567, 0.9555, 0.9557, 0.9569, 0.9563, 0.9563, 0.9557, 0.9561, 0.9562, 0.9552, 0.9561, 0.9554, 0.9551, 0.9557]

# %%
x = 108
plt.plot(range(x), acc_tests0, label="without processing", linewidth=2)
plt.plot(range(x), acc_tests1, label="with Cutout", linewidth=2)
plt.plot(range(x), acc_tests2[:108], label="with AutoAugmentation", linewidth=2)

plt.legend(loc='lower right')
plt.xlabel('iterations')
plt.ylabel('accuracy')
plt.title("accuracy with different training pipeline")
plt.ylim(0.6, 1.0)
plt.grid()
plt.savefig("summary for train methods")

# %%
plt.plot(range(200), acc_tests2, label="validation accuracy", linewidth=2)
plt.plot(range(200), acc_train2, label="train accuracy", linewidth=2)

print(max(acc_tests2))
plt.legend(loc='lower right')
plt.xlabel('iterations')
plt.ylabel('accuracy')
plt.title("accuracies with AutoAugmentation")
plt.ylim(0.6, 1.0)
plt.grid()
plt.savefig("train model with autoaug 200")
# Out:
# 0.9609

# %%
plt.plot(range(200), acc_testsf, label="validation accuracy", linewidth=2)
plt.plot(range(200), acc_trainf, label="train accuracy", linewidth=2)

print(max(acc_testsf))
plt.legend(loc='lower right')
plt.xlabel('iterations')
plt.ylabel('accuracy')
plt.title("accuracies with Cutout")
plt.ylim(0.7, 1.0)
plt.grid()
plt.savefig("train model with cutout 200")
# Out:
# 0.9569

# %%
acc = [0.0,
0.9124078512191772,
0.9189132577180863,
0.9191651594638824,
0.9190760159492493,
0.918828119635582,
0.9185096094012261,
0.9173091879487038,
0.9108678814768791,
0.8798357304930687,
0.6430002948641778,
0.04177984893321991,
0.0]

plt.plot(range(13)[::-1], acc, linewidth=2)

# plt.legend(loc='lower right')
plt.xlabel('number of edges')
plt.ylabel('accuracy')
plt.grid()
plt.savefig("accuracy with different number of edges")
